# %% [markdown]
# # Notebook de Scrapping de données
# ## Le scrapping
# On va utiliser la librairy BeautifulSoup pour scrapper (récupérer) les données à partir d'un site web, puis les insérer dans un fichier CSV afin de les exploités.
# ## Les données
# On récupère les données depuis le site web d'allociné. Il contient la plus grosse base francophone de films. On va y récupéré une très grosse quantité de données.

# %%
# Importation des bibliothèques
import requests
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor, as_completed
import csv
import base64

# %%
# On récupère l'url de la page
url = "https://www.allocine.fr/films/decennie-2000/?page="

# %%
# On test si l'url est valide avec une requête HTTP afin de récupérer le code source de la page
response = requests.get(url)
response.raise_for_status()

# %%
# Si la requête est valide, on récupère le code source de la page
soup = BeautifulSoup(response.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="fr">
# <head>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8">
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="noindex, nofollow" name="robots">
# <title>Les films les plus populaires - AlloCiné</title>
# <meta content="" name="keywords"/>
# <meta content="noarchive" name="Googlebot"/>
# <meta content="global" name="distribution"/>
# <meta content="AlloCine" name="author"/>
# <meta content="France" name="country"/>
# <meta content="48.87078;2.30447" name="geo.position"/>
# <meta content="FR" name="geo.country"/>
# <meta content="48.87078;2.30447" name="ICBM"/>
# <meta content="#FECC00" name="theme-color"/>
# <meta content="Découvrez tous les films les plus populaires sur AlloCiné, comme :  Un homme est mort, Josey Wales hors la loi, Emmanuelle" name="description"/>
# <meta content="AlloCiné" property="og:site_name"/>
# <meta content="fr_FR" property="og:locale"/>
# <meta content="Les films les plus populaires sur AlloCiné" property="og:title"/>
# <meta content="Découvrez tous les films les plus populaires sur AlloCiné" property="og:description"/>
# <meta content="99197768694" property="fb:app_id"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@allocine" name="twitter:site"/>
# <meta content="Les films les plus populaires sur AlloCiné" name="twitter:title"/>
# <meta content="Découvrez tous les films les plus populaires sur AlloCiné" name="twitter:description"/>
# <meta content="" name="twitter:image"/>
# <meta content="allocine" name="twitter:app:name:iphone"/>
# <meta content="allocine" name="twitter:app:name:ipad"/>
# <meta content="allocine" name="twitter:app:name:googleplay"/>
# <meta content="allocine://open/" name="twitter:app:url:iphone"/>
# <meta content="allocine://open/" name="twitter:app:url:ipad"/>
# <meta content="allocine://open/" name="twitter:app:url:googleplay"/>
# <meta content="351184863" name="twitter:app:id:iphone"/>
# <meta content="351184863" name="twitter:app:id:ipad"/>
# <meta content="com.allocine.androidapp" name="twitter:app:id:googleplay"/>
# <meta content="app-id=351184863, app-argument=allocine://open/" name="apple-itunes-app"/>
# <meta content="107276450147" property="fb:pages">
# <link href="https://assets.allocine.fr" rel="preconnect"/>
# <link as="font" crossorigin="" href="https://assets.allocine.fr/skin/font/icon/font-icon.woff2" rel="preload" type="font/woff2"/>
# <link as="image" href="https://assets.allocine.fr/skin/img/allocine/logo-main-grey.5de8867c.svg" rel="preload" type="image/svg+xml"/>
# <link as="script" href="https://assets.allocine.fr/js/website/website-common.e0dd554d7d10ff11a60d.js" rel="preload"/>
# <link as="script" href="https://assets.allocine.fr/js/website/movies.c0944689a2b67f17bb03.js" rel="preload"/>
# <link href="https://sdk.privacy-center.org/" rel="preconnect"/>
# <style>article,aside,details,figcaption,figure,footer,header,hgroup,nav,section,summary{display:block}audio,canvas,video{display:inline-block}audio:not([controls]){display:none;height:0}[hidden],template{display:none}html{background:#fff;color:#000;-webkit-text-size-adjust:100%;-ms-text-size-adjust:100%}button,html,input,select,textarea{font-family:sans-serif}body{margin:0}a{background:transparent}a:focus{outline:thin dotted}a:active,a:hover{outline:0}abbr[title]{border-bottom:1px dotted}b,strong{font-weight:700}dfn{font-style:italic}mark{background:#ff0;color:#000}code,kbd,pre,samp{font-family:monospace,serif;font-size:1em}pre{white-space:pre;white-space:pre-wrap;word-wrap:break-word}q{quotes:"\00201c" "\00201d" "\002018" "\002019"}q:after,q:before{content:"";content:none}small{font-size:80%}sub,sup{font-size:75%;line-height:0;position:relative;vertical-align:baseline}sup{top:-.5em}sub{bottom:-.25em}img{border:0}svg:not(:root){overflow:hidden}figure{margin:0}fieldset{border:1px solid #ececec;margin:0 2px;padding:.35em .625em .75em}legend{border:0;padding:0;white-space:normal}button,input,select,textarea{font-family:inherit;font-size:100%;margin:0;vertical-align:baseline}button,input{line-height:normal}button,select{text-transform:none}button,html input[type=button],input[type=reset],input[type=submit]{-webkit-appearance:button;cursor:pointer}button[disabled],input[disabled]{cursor:default}input[type=checkbox],input[type=radio]{box-sizing:border-box;padding:0}input[type=search]{-webkit-appearance:textfield;box-sizing:content-box}input[type=search]::-webkit-search-cancel-button,input[type=search]::-webkit-search-decoration{-webkit-appearance:none}button::-moz-focus-inner,input::-moz-focus-inner{border:0;padding:0}textarea{overflow:auto;vertical-align:top}table{border-collapse:collapse;border-spacing:0}em{font-style:normal}*,:after,:before{box-sizing:border-box}::-moz-selection{background:#b3d4fc;text-shadow:none}::selection{background:#b3d4fc;text-shadow:none}input:focus{outline:none}p{margin:0}h1,h2,h3,h4,h5,h6{margin:0;padding:0;font-size:1em}hr{display:block;height:1px;border:0;margin:1em 0;padding:0}audio,canvas,img,video{vertical-align:middle}fieldset,textarea{border:0;margin:0;padding:0}textarea{resize:vertical;outline:0;font-size:13px;width:100%}li,ol,ul{list-style:none;margin:0;padding:0}address{font-style:normal}iframe{border:0}.alert:before,.dropdown-custom .btn,.dropdown-select:after,.filter-entity-on .item-content:after,.icon:after,.icon:before,.more-trigger:after,.rating-star:before{font-family:font-icon;font-style:normal;font-weight:400;font-variant:normal;text-transform:none;speak:none;display:inline-block;vertical-align:middle;margin:0 .375rem;line-height:1;-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale}.icon:after{margin-right:0}.icon:before{margin-left:0}.icon{font-size:1rem}.no-icon{display:none}.icon-centered:after,.icon-centered:before{margin:auto}.icon-3d-a:after,.icon-3d:before{content:"\e001"}.icon-3dots-a:after,.icon-3dots:before{content:"\e002"}.icon-4demotion-a:after,.icon-4demotion:before{content:"\e003"}.icon-4dx-a:after,.icon-4dx:before{content:"\e004"}.icon-4k-a:after,.icon-4k:before{content:"\e005"}.icon-4k3d-a:after,.icon-4k3d:before{content:"\e006"}.icon-add-to-collections-a:after,.icon-add-to-collections:before{content:"\e007"}.icon-alert-danger-a:after,.icon-alert-danger:before{content:"\e008"}.icon-alert-default-a:after,.icon-alert-default:before{content:"\e009"}.icon-alert-disclaimer-a:after,.icon-alert-disclaimer:before{content:"\e00a"}.icon-alert-info-a:after,.icon-alert-info:before{content:"\e00b"}.icon-alert-success-a:after,.icon-alert-success:before{content:"\e00c"}.icon-alert-warning-a:after,.icon-alert-warning:before{content:"\e00d"}.icon-android-a:after,.icon-android:before{content:"\e00e"}.icon-apple-a:after,.icon-apple:before{content:"\e00f"}.icon-arrow-bottom-a:after,.icon-arrow-bottom:before{content:"\e010"}.icon-arrow-left-a:after,.icon-arrow-left:before{c ...
# <script type="text/javascript">
# !function(a){var c="rcblock",e="rc-ko",t=localStorage.getItem(c);t===e&&(document.getElementsByTagName("html")[0].classList.add("m-ac-g-a"),a.RCBLOCK=!0)}(window);
# </script>
# <script type="text/javascript">
# (function(global) {
#     var fontStyleKey      = 'font_css_code';
#     var fontCssUrlKey     = 'font_css_url';
#     var brand             = 'allocine';
#     var fontCss           = localStorage.getItem(fontStyleKey);
#     var distantFontHash   = localStorage.getItem(fontCssUrlKey);
#     var currentFontHash   = 'https\u003A\/\/assets.allocine.fr\/skin\/css\/allocine\/font.min.7c570837.css';
#
#     if (fontCss && distantFontHash && (distantFontHash === currentFontHash)) {
#         var style           = document.createElement('style');
#             style.type      = 'text/css';
#             style.innerHTML = fontCss;
#
#       document.head.appendChild(style);
#
#       global.AC_FONT_LOADED = true;
#     }
# }(window));
# </script>
# <link href="https://assets.allocine.fr/favicon/allocine.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://assets.allocine.fr/favicon/allocine.ico" rel="icon" type="image/ico"/>
# <link href="https://assets.allocine.fr/apple-touch-icon/allocine.png" rel="apple-touch-icon"/>
# <link href="https://twitter.com/allocine" rel="me">
# </link></meta></meta></meta></head>
# <body class="allocine allocine__movies_all logged-out" data-migration="graph" id="allocine__movies_all">
# <div class="sub-body">
# <div class="js-interstitial ad-interstitial ad-item" id="dfp-interstitial"></div>
# <header class="header-main" id="header-main">
# <div class="header-main-center">
# <div class="header-main-top">
# <div aria-label="Bouton Menu mobile" class="header-main-btn-mobile icon icon-hamburger" id="header-main-mobile-btn-menu"></div>
# <div class="header-main-logo-holder">
# <span class="ACrLw=ACr= header-main-logo">
# <img alt="allocine" class="header-main-logo-img" height="37" src="https://assets.allocine.fr/skin/img/allocine/logo-main.ab1b33da.svg" width="162"/>
# <span class="header-main-logo-name">AlloCiné</span>
# </span>
# </div>
# <form action="/rechercher/" class="header-main-search" id="search-header" method="get">
# <fieldset class="header-main-search-fieldset" id="search-engine">
# <div class="header-search-form-container"><input class="header-search-input" id="header-search-input" name="site_search[q]" placeholder="Rechercher un film, une série, une star..." type="text"/><button aria-label="Envoyer" class="header-search-submit icon icon-search" title="Rechercher" type="submit"></button></div> </fieldset>
# <p class="header-search-extralinks">
# Ex. :
# <span class="ACrL3RACrhZy0xMDI2L2ZpbG1zLw==">Meilleurs films pour ados</span>, <span class="ACrL3RACrhZy01MTg1L2ZpbG1zLw==">Meilleurs films de mafieux</span> </p>
# <div class="header-main-search-mobile-layer" id="header-main-search-mobile-layer"></div>
# </form>
# <div class="header-ads-zone">
# <div class="js-headerlink ad-headerlink ad-item" id="dfp-headerlink"></div>
# </div>
# <div aria-label="Bouton Rechercher" class="header-main-btn-mobile icon icon-search" id="header-main-mobile-btn-search"></div>
# <div class="header-main-btn-mobile header-main-mobile-btn-userspace" data-ga='{"eventCategory":"my_brand","eventAction":"header_button","eventLabel":"test_cta_mac","dimension10":"movies_all"}' data-ga-trigger="clic" id="header-main-mobile-btn-userspace">
# <span aria-label="Bouton Mon compte" class="icon icon-profil"></span>
# <img alt="" class="avatar js-myaccount-avatar" src="..."/>
# </div>
# </div>
# <div class="header-main-bottom">
# <nav class="header-main-nav" id="header-main-nav"><ul class="header-nav-holder"><li class="header-nav-item"><span class="ACrL25ACrld3Mv header-nav-link" title="News">
# News
# </span></li><li class="header-nav-item is-active"><span class="ACrL2ZACrpbG0v header-nav-link current ancestor" title="Cinéma">
# Cinéma
# </span><div class="header-main-subnav-holder"><ul class="header-main-subnav"><li class="header-subnav-item"><span class="ACrL2ZACrpbG0vbWVpbGxldXJzLw== header-nav-link" title="Meilleurs films">
# Meilleurs films
# </span></li><li class="header-subnav-item"><span class="ACrL2ZACrpbG0vYXVjaW5lbWEv header-nav-link" title="Films à l'affiche">
# Films à l'affiche
# </span></li><li class="header-subnav-item"><span class="ACrL2ZACrpbG0vYXR0ZW5kdXMv header-nav-link" title="Prochainement">
# Prochainement
# </span></li><li class="header-subnav-item"><span class="ACrL3NACrhbGxlLw== header-nav-link" title="Séances">
# Séances
# </span></li><li class="header-subnav-item"><span class="ACrL2tACrpZHMv header-nav-link" data-ga='{"hitType":"event","eventCategory":"op-kids","eventLabel":"https:\/\/www.allocine.fr\/films\/decennie-1970\/","eventAction":"navigation_menu_click"}' data-ga-trigger="clic" data-jan='{"eventAction":"click","eventName":"internal","position_name":"kids_menu","filters_value":"https:\/\/www.allocine.fr\/films\/decennie-1970\/"}' title="Kids">
# Kids
# </span></li><li class="header-subnav-item"><span class="ACrL2JACrveG9mZmljZS9mcmFuY2Uv header-nav-link" title="Box Office">
# Box Office
# </span></li><li class="header-subnav-item"><span class="ACrL2ZACrpbG0vY291cnQtbWV0cmFnZS8= header-nav-link" title="Courts-métrages">
# Courts-métrages
# </span></li><li class="header-subnav-item"><span class="ACrL2RACr2ZC8= header-nav-link" title="DVD">
# DVD
# </span></li><li class="header-subnav-item is-active"><span class="ACrL2ZACrpbG1zLw== header-nav-link current" title="Tous les films">
# Tous les films
# </span></li></ul></div></li><li class="header-nav-item"><span class="ACrL3NACrlcmllcy8= header-nav-link" title="Séries">
# Séries
# </span></li><li class="header-nav-item"><span class="ACrL3NACr0cmVhbWluZy8= header-nav-link" data-ga='{"hitType":"event","eventCategory":"op-svod","eventLabel":"https:\/\/www.allocine.fr\/films\/decennie-1970\/","eventAction":"navigation_menu_click"}' data-ga-trigger="clic" data-jan='{"eventAction":"click","eventName":"internal","position_name":"navigation_menu_click","filters_value":"https:\/\/www.allocine.fr\/films\/decennie-1970\/"}' title="Streaming">
# Streaming
# </span></li><li class="header-nav-item"><span class="ACrL3RACr2YWN0dS8= header-nav-link" title="TVActu">
# TVActu
# </span></li><li class="header-nav-item"><span class="ACrL3RACryYWlsZXIv header-nav-link" title="Trailers">
# Trailers
# </span></li><li class="header-nav-item"><span class="ACrL3ZACrvZC8= header-nav-link" title="VOD">
# VOD
# </span></li><li class="header-nav-item"><span class="ACrL2ZACrpbG0vbGVzaW5kZXMv header-nav-link" title="Les indés">
# Les indés
# </span></li><li class="header-nav-item"><span class="ACrL21ACr5Y2FuYWwv header-nav-link" title="Canal+">
# Canal+
# </span></li><style>
# .header-nav-holder .nav-ope-spec .header-nav-link {
#     padding-right: 0;
# }
#
# .logo-tab-desktop {
#     display:none;
# }
#
# @media (min-width: 62.0625em) {
#     .header-nav-holder > li > .header-nav-link {
#         padding-right: 0.5rem;
#         padding-left: 0.5rem;
#     }
#     .header-nav-holder .nav-ope-spec .header-nav-link {
#         background: none;
#     }
#
#     .header-nav-holder .nav-ope-spec .header-nav-link img.ope_spec_1,
#     .header-nav-holder .nav-ope-spec .header-nav-link img.ope_spec_2,
#     .header-nav-holder .nav-ope-spec .header-nav-link img.ope_spec_3{
#         margin-top: -0.3125rem;
#     }
#
#     .logo-tab-desktop {
#         display: block;
#     }
#
#     .logo-tab-mobile {
#         display: none;
#     }
# }
# </style><li class="nav-ope-spec"><span class="ACraHRACr0cHM6Ly9jb2x1bWJpYXBpY3R1cmVzMTAwLmFsbG9jaW5lLmZyLz91dG1fc291cmNlPWFsbG9jaW5lJnV0bV9tZWRpdW09b25nbGV0SFAmdXRtX2NhbXBhaWduPTEwMGFuc2NvbHVtYmlh header-nav-link" rel="noopener" target="_blank"><img alt="100 ans de Columbia" class="logo-tab-desktop ope_spec_1" height="25" src="https://fr.web.img4.acsta.net/commons/v9/allocine/ope_spec/onglet-100ans-desktop4.jpg" width="110"/><img alt="100 ans de Columbia" class="logo-tab-mobile ope_spec_1" height="25" src="https://fr.web.img2.acsta.net/commons/v9/allocine/ope_spec/onglet-100ans-desktop4.png" width="110"/></span></li></ul></nav><div class="header-userspace-nav" id="header-userspace-nav"><span aria-label="Bouton Mon compte" class="ACrLy9ACrtb24uYWxsb2NpbmUuZnIv header-nav-userspace-upper-link" data-ga='{"eventCategory":"my_brand","eventAction":"header_button","eventLabel":"test_cta_mac","dimension10":"movies_all"}' data-ga-trigger="clic"><img alt="" class="avatar js-myaccount-avatar" src="..."/>
# Mon compte
# </span><div class="header-nav-userspace-holder"><div class="header-nav-userspace-sso"><span class="ACrLy9ACrtb24uYWxsb2NpbmUuZnIvY29ubmV4aW9uLz9yZXR1cm5Vcmw9aHR0cHMlM0ElMkYlMkZ3d3cuYWxsb2NpbmUuZnIlMkZmaWxtcyUyRmRlY2VubmllLTE5NzAlMkY= button button-social-ac-ghost button-sm sign-in"><span class="txt">Identifiez-vous</span></span><span class="ACrLy9ACrtb24uYWxsb2NpbmUuZnIvaW5zY3JpcHRpb24vP3JldHVyblVybD0lMkYlMkZtb24uYWxsb2NpbmUuZnIlMkY= button button-social-ac-full button-sm sign-up"><span class="txt">Créez votre compte</span></span></div><ul class="header-nav-userspace-subcontent"></ul></div></div> </div>
# </div>
# </header>
# <div class="main-banner">
# <div class="js-masthead ad-masthead ad-item" id="dfp-masthead"></div>
# </div>
# <main class="content-layout cf" id="content-layout">
# <div class="section-wrap breadcrumb">
# <a class="item" href="/">Accueil</a><a class="item" href="/film/">Cinéma</a><a class="item" href="/film/meilleurs/">Les meilleurs films</a><a class="item" href="/films/">Les films les plus populaires</a><h1 class="item">
# Tous les films </h1></div>
# <section class="section-wrap">
# <div class="titlebar titlebar-page"><div class="titlebar-title titlebar-title-xl">Tous les films</div><div class="light titlebar-subtile"><span class="titlebar-subtile-txt">Retrouvez les films les plus populaires sur AlloCiné, à voir ou à revoir, seul, en famille ou entre amis.</span></div></div>
# </section>
# <section class="section-wrap">
# <nav class="third-nav third-nav-hash js-third-nav">
# <span class="ACrL2ZACrpbG1zL2RvY3VtZW50YWlyZXMv item">Documentaires</span> <span class="ACrL2ZACrpbG0vZW5mYW50cy8= item js-item-mq-medium">Films pour enfants</span> <span class="ACrL25ACrldGZsaXgvZmlsbS90b3VzLw== item js-item-mq-medium">Films sur Netflix</span> <span class="ACrL21ACr5Y2FuYWwvZmlsbS90b3VzLw== item js-item-mq-medium">Films sur CANAL+</span>
# <div class="item-more js-third-sub-nav-holder">
# <span aria-label="Afficher plus d'éléments" class="item-more-picto icon icon-plus-mini plus-mini-rounded js-trigger-third-nav-sub" role="button"></span>
# <div class="third-nav-sub js-third-nav-sub">
# <span class="ACrL2FACrtYXpvbi9maWxtL3RvdXMv item">Films sur Prime Video</span> <span class="ACrL3ZACrvZC9maWxtcy8= item">Films en VOD</span> <span class="ACrL2RACr2ZC8= item">Films en DVD</span> <span class="ACrL2JACrvL2ZpbG1zLw== item">BO de films</span>
# </div>
# </div>
# </nav>
# </section>
# <section class="section section-wrap gd-3-cols gd-gap-20">
# <div class="gd-col-left">
# <div class="filter-entity" id="filter-entity">
# <div class="filter-entity-title">Filtres</div>
# <div class="filter-entity-mobile loading filter-count-3" id="filter-entity-mobile"></div>
# <div class="filter-entity-desktop">
# <div class="filter-entity-section">
# <div class="filter-entity-subtitle icon js-more-trigger">
# Par genres
# </div>
# <ul class="filter-entity-word" data-name="Par genres">
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDI1L2RlY2VubmllLTE5NzAv item-content" title="Action">Action</span>
# <span class="light">(526)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDI2L2RlY2VubmllLTE5NzAv item-content" title="Animation">Animation</span>
# <span class="light">(83)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDE2L2RlY2VubmllLTE5NzAv item-content" title="Arts Martiaux">Arts Martiaux</span>
# <span class="light">(106)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDAxL2RlY2VubmllLTE5NzAv item-content" title="Aventure">Aventure</span>
# <span class="light">(363)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDI3L2RlY2VubmllLTE5NzAv item-content" title="Biopic">Biopic</span>
# <span class="light">(87)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDQ3L2RlY2VubmllLTE5NzAv item-content" title="Bollywood">Bollywood</span>
# <span class="light">(1)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDQwL2RlY2VubmllLTE5NzAv item-content" title="Classique">Classique</span>
# <span class="light">(2)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDA1L2RlY2VubmllLTE5NzAv item-content" title="Comédie">Comédie</span>
# <span class="light">(1096)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDAyL2RlY2VubmllLTE5NzAv item-content" title="Comédie dramatique">Comédie dramatique</span>
# <span class="light">(564)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDEzL2RlY2VubmllLTE5NzAv item-content" title="Comédie musicale">Comédie musicale</span>
# <span class="light">(58)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDQ5L2RlY2VubmllLTE5NzAv item-content" title="Concert">Concert</span>
# <span class="light">(3)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDE3L2RlY2VubmllLTE5NzAv item-content" title="Divers">Divers</span>
# <span class="light">(1030)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDU0L2RlY2VubmllLTE5NzAv item-content" title="Drama">Drama</span>
# <span class="light">(1)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDA4L2RlY2VubmllLTE5NzAv item-content" title="Drame">Drame</span>
# <span class="light">(2195)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDA5L2RlY2VubmllLTE5NzAv item-content" title="Epouvante-horreur">Epouvante-horreur</span>
# <span class="light">(477)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDEwL2RlY2VubmllLTE5NzAv item-content" title="Erotique">Erotique</span>
# <span class="light">(268)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDIyL2RlY2VubmllLTE5NzAv item-content" title="Espionnage">Espionnage</span>
# <span class="light">(39)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDMzL2RlY2VubmllLTE5NzAv item-content" title="Expérimental">Expérimental</span>
# <span class="light">(13)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDM2L2RlY2VubmllLTE5NzAv item-content" title="Famille">Famille</span>
# <span class="light">(103)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDEyL2RlY2VubmllLTE5NzAv item-content" title="Fantastique">Fantastique</span>
# <span class="light">(193)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDE0L2RlY2VubmllLTE5NzAv item-content" title="Guerre">Guerre</span>
# <span class="light">(128)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDE1L2RlY2VubmllLTE5NzAv item-content" title="Historique">Historique</span>
# <span class="light">(162)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDMxL2RlY2VubmllLTE5NzAv item-content" title="Judiciaire">Judiciaire</span>
# <span class="light">(20)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDQzL2RlY2VubmllLTE5NzAv item-content" title="Musical">Musical</span>
# <span class="light">(96)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDQ4L2RlY2VubmllLTE5NzAv item-content" title="Opéra">Opéra</span>
# <span class="light">(4)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDE4L2RlY2VubmllLTE5NzAv item-content" title="Policier">Policier</span>
# <span class="light">(505)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDI4L2RlY2VubmllLTE5NzAv item-content" title="Péplum">Péplum</span>
# <span class="light">(4)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDI0L2RlY2VubmllLTE5NzAv item-content" title="Romance">Romance</span>
# <span class="light">(286)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDIxL2RlY2VubmllLTE5NzAv item-content" title="Science Fiction">Science Fiction</span>
# <span class="light">(180)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDUxL2RlY2VubmllLTE5NzAv item-content" title="Spectacle">Spectacle</span>
# <span class="light">(1)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDIzL2RlY2VubmllLTE5NzAv item-content" title="Thriller">Thriller</span>
# <span class="light">(533)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDE5L2RlY2VubmllLTE5NzAv item-content" title="Western">Western</span>
# <span class="light">(239)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDUwL2RlY2VubmllLTE5NzAv item-content" title="Évènement Sportif">Évènement Sportif</span>
# <span class="light">(7)</span> </li>
# </ul>
# </div>
# <div class="filter-entity-on" data-name="Années">
# <strong>Années</strong> :
# <span class="filter-entity-on-txt" data-name="1970-1979">
# 1970-1979 <span class="ACrL2ZACrpbG1zLw== item-content"> </span>
# </span>
# </div>
# <div class="filter-entity-section">
# <div class="filter-entity-subtitle icon js-more-trigger active">
# Par années
# </div>
# <ul class="filter-entity-word" data-name="Par années">
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2RlY2VubmllLTE5NzAvYW5uZWUtMTk3OS8= item-content" title="1979">1979</span>
# <span class="light">(683)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2RlY2VubmllLTE5NzAvYW5uZWUtMTk3OC8= item-content" title="1978">1978</span>
# <span class="light">(657)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2RlY2VubmllLTE5NzAvYW5uZWUtMTk3Ny8= item-content" title="1977">1977</span>
# <span class="light">(652)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2RlY2VubmllLTE5NzAvYW5uZWUtMTk3Ni8= item-content" title="1976">1976</span>
# <span class="light">(668)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2RlY2VubmllLTE5NzAvYW5uZWUtMTk3NS8= item-content" title="1975">1975</span>
# <span class="light">(612)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2RlY2VubmllLTE5NzAvYW5uZWUtMTk3NC8= item-content" title="1974">1974</span>
# <span class="light">(661)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2RlY2VubmllLTE5NzAvYW5uZWUtMTk3My8= item-content" title="1973">1973</span>
# <span class="light">(651)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2RlY2VubmllLTE5NzAvYW5uZWUtMTk3Mi8= item-content" title="1972">1972</span>
# <span class="light">(666)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2RlY2VubmllLTE5NzAvYW5uZWUtMTk3MS8= item-content" title="1971">1971</span>
# <span class="light">(616)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL2RlY2VubmllLTE5NzAvYW5uZWUtMTk3MC8= item-content" title="1970">1970</span>
# <span class="light">(627)</span> </li>
# </ul>
# </div>
# <div class="filter-entity-section">
# <div class="filter-entity-subtitle icon js-more-trigger">
# Par pays
# </div>
# <ul class="filter-entity-word" data-name="Par pays">
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTAwMS9kZWNlbm5pZS0xOTcwLw== item-content" title="France">France</span>
# <span class="light">(1577)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTAwMi9kZWNlbm5pZS0xOTcwLw== item-content" title="U.S.A.">U.S.A.</span>
# <span class="light">(1595)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTAwNy9kZWNlbm5pZS0xOTcwLw== item-content" title="Afrique du Sud">Afrique du Sud</span>
# <span class="light">(6)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTEyOC9kZWNlbm5pZS0xOTcwLw== item-content" title="Albanie">Albanie</span>
# <span class="light">(7)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTAxMy9kZWNlbm5pZS0xOTcwLw== item-content" title="Algérie">Algérie</span>
# <span class="light">(17)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTEyOS9kZWNlbm5pZS0xOTcwLw== item-content" title="Allemagne">Allemagne</span>
# <span class="light">(130)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTAwMy9kZWNlbm5pZS0xOTcwLw== item-content" title="Allemagne de l'Est">Allemagne de l'Est</span>
# <span class="light">(16)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTEzMC9kZWNlbm5pZS0xOTcwLw== item-content" title="Allemagne de l'Ouest">Allemagne de l'Ouest</span>
# <span class="light">(249)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNzI0Mi9kZWNlbm5pZS0xOTcwLw== item-content" title="Andorre">Andorre</span>
# <span class="light">(1)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTA0NC9kZWNlbm5pZS0xOTcwLw== item-content" title="Angola">Angola</span>
# <span class="light">(1)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTAyNS9kZWNlbm5pZS0xOTcwLw== item-content" title="Argentine">Argentine</span>
# <span class="light">(21)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTAxNi9kZWNlbm5pZS0xOTcwLw== item-content" title="Arménie">Arménie</span>
# <span class="light">(2)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTAyOS9kZWNlbm5pZS0xOTcwLw== item-content" title="Australie">Australie</span>
# <span class="light">(45)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTAzMi9kZWNlbm5pZS0xOTcwLw== item-content" title="Autriche">Autriche</span>
# <span class="light">(17)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTAxNC9kZWNlbm5pZS0xOTcwLw== item-content" title="Belgique">Belgique</span>
# <span class="light">(83)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTA3Mi9kZWNlbm5pZS0xOTcwLw== item-content" title="Bengladesh">Bengladesh</span>
# <span class="light">(1)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTA1NS9kZWNlbm5pZS0xOTcwLw== item-content" title="Bolivie">Bolivie</span>
# <span class="light">(1)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTAyOC9kZWNlbm5pZS0xOTcwLw== item-content" title="Brésil">Brésil</span>
# <span class="light">(72)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTA2NC9kZWNlbm5pZS0xOTcwLw== item-content" title="Bulgarie">Bulgarie</span>
# <span class="light">(7)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTExMS9kZWNlbm5pZS0xOTcwLw== item-content" title="Bénin">Bénin</span>
# <span class="light">(1)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTA0Ny9kZWNlbm5pZS0xOTcwLw== item-content" title="Cameroun">Cameroun</span>
# <span class="light">(3)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTAxOC9kZWNlbm5pZS0xOTcwLw== item-content" title="Canada">Canada</span>
# <span class="light">(126)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTA1OS9kZWNlbm5pZS0xOTcwLw== item-content" title="Chili">Chili</span>
# <span class="light">(8)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTAyNy9kZWNlbm5pZS0xOTcwLw== item-content" title="Chine">Chine</span>
# <span class="light">(22)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTA2NS9kZWNlbm5pZS0xOTcwLw== item-content" title="Colombie">Colombie</span>
# <span class="light">(1)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTA1Ny9kZWNlbm5pZS0xOTcwLw== item-content" title="Corée">Corée</span>
# <span class="light">(8)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTAwOC9kZWNlbm5pZS0xOTcwLw== item-content" title="Corée du Sud">Corée du Sud</span>
# <span class="light">(20)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTA2MC9kZWNlbm5pZS0xOTcwLw== item-content" title="Cuba">Cuba</span>
# <span class="light">(7)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTEyMy9kZWNlbm5pZS0xOTcwLw== item-content" title="Côte-d'Ivoire">Côte-d'Ivoire</span>
# <span class="light">(2)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTA2MS9kZWNlbm5pZS0xOTcwLw== item-content" title="Danemark">Danemark</span>
# <span class="light">(14)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTA2My9kZWNlbm5pZS0xOTcwLw== item-content" title="Egypte">Egypte</span>
# <span class="light">(11)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTEzNC9kZWNlbm5pZS0xOTcwLw== item-content" title="Equateur">Equateur</span>
# <span class="light">(1)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTAxNy9kZWNlbm5pZS0xOTcwLw== item-content" title="Espagne">Espagne</span>
# <span class="light">(226)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTA2OS9kZWNlbm5pZS0xOTcwLw== item-content" title="Finlande">Finlande</span>
# <span class="light">(20)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTAwNC9kZWNlbm5pZS0xOTcwLw== item-content" title="Grande-Bretagne">Grande-Bretagne</span>
# <span class="light">(492)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTAxOS9kZWNlbm5pZS0xOTcwLw== item-content" title="Grèce">Grèce</span>
# <span class="light">(22)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTExOS9kZWNlbm5pZS0xOTcwLw== item-content" title="Géorgie">Géorgie</span>
# <span class="light">(1)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTA4My9kZWNlbm5pZS0xOTcwLw== item-content" title="Haïti">Haïti</span>
# <span class="light">(1)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTE0Mi9kZWNlbm5pZS0xOTcwLw== item-content" title="Hong-Kong">Hong-Kong</span>
# <span class="light">(168)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTA2OC9kZWNlbm5pZS0xOTcwLw== item-content" title="Hongrie">Hongrie</span>
# <span class="light">(58)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTA0Mi9kZWNlbm5pZS0xOTcwLw== item-content" title="Inde">Inde</span>
# <span class="light">(49)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTA3MC9kZWNlbm5pZS0xOTcwLw== item-content" title="Indonésie">Indonésie</span>
# <span class="light">(3)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTA4Ni9kZWNlbm5pZS0xOTcwLw== item-content" title="Iran">Iran</span>
# <span class="light">(32)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTAzMC9kZWNlbm5pZS0xOTcwLw== item-content" title="Irlande">Irlande</span>
# <span class="light">(5)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTAzNy9kZWNlbm5pZS0xOTcwLw== item-content" title="Israël">Israël</span>
# <span class="light">(38)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTAyMC9kZWNlbm5pZS0xOTcwLw== item-content" title="Italie">Italie</span>
# <span class="light">(910)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTAyMi9kZWNlbm5pZS0xOTcwLw== item-content" title="Jamaïque">Jamaïque</span>
# <span class="light">(2)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTAyMS9kZWNlbm5pZS0xOTcwLw== item-content" title="Japon">Japon</span>
# <span class="light">(249)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTA5NC9kZWNlbm5pZS0xOTcwLw== item-content" title="Koweit">Koweit</span>
# <span class="light">(2)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTEwMS9kZWNlbm5pZS0xOTcwLw== item-content" title="Lettonie">Lettonie</span>
# <span class="light">(1)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTA0OS9kZWNlbm5pZS0xOTcwLw== item-content" title="Liban">Liban</span>
# <span class="light">(7)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTE0Ny9kZWNlbm5pZS0xOTcwLw== item-content" title="Libye">Libye</span>
# <span class="light">(1)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTE3OC9kZWNlbm5pZS0xOTcwLw== item-content" title="Liechtenstein">Liechtenstein</span>
# <span class="light">(3)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTA4Ny9kZWNlbm5pZS0xOTcwLw== item-content" title="Lituanie">Lituanie</span>
# <span class="light">(1)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTAzOC9kZWNlbm5pZS0xOTcwLw== item-content" title="Mali">Mali</span>
# <span class="light">(2)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTAzMy9kZWNlbm5pZS0xOTcwLw== item-content" title="Maroc">Maroc</span>
# <span class="light">(9)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTEwMy9kZWNlbm5pZS0xOTcwLw== item-content" title="Mauritanie">Mauritanie</span>
# <span class="light">(1)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTAzMS9kZWNlbm5pZS0xOTcwLw== item-content" title="Mexique">Mexique</span>
# <span class="light">(53)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTE3MS9kZWNlbm5pZS0xOTcwLw== item-content" title="Monaco">Monaco</span>
# <span class="light">(2)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTEwNC9kZWNlbm5pZS0xOTcwLw== item-content" title="Mongolie">Mongolie</span>
# <span class="light">(2)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTAzNC9kZWNlbm5pZS0xOTcwLw== item-content" title="Nigéria">Nigéria</span>
# <span class="light">(5)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTA2Mi9kZWNlbm5pZS0xOTcwLw== item-content" title="Norvège">Norvège</span>
# <span class="light">(9)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTAwNS9kZWNlbm5pZS0xOTcwLw== item-content" title="Nouvelle-Zélande">Nouvelle-Zélande</span>
# <span class="light">(5)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTE1NS9kZWNlbm5pZS0xOTcwLw== item-content" title="Pakistan">Pakistan</span>
# <span class="light">(1)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTExNi9kZWNlbm5pZS0xOTcwLw== item-content" title="Panama">Panama</span>
# <span class="light">(2)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTE3Ny9kZWNlbm5pZS0xOTcwLw== item-content" title="Pays-Bas">Pays-Bas</span>
# <span class="light">(18)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTExNS9kZWNlbm5pZS0xOTcwLw== item-content" title="Philippines">Philippines</span>
# <span class="light">(23)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTAyMy9kZWNlbm5pZS0xOTcwLw== item-content" title="Pologne">Pologne</span>
# <span class="light">(38)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNzIzNi9kZWNlbm5pZS0xOTcwLw== item-content" title="Porto Rico">Porto Rico</span>
# <span class="light">(1)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTAyNC9kZWNlbm5pZS0xOTcwLw== item-content" title="Portugal">Portugal</span>
# <span class="light">(15)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTA1MS9kZWNlbm5pZS0xOTcwLw== item-content" title="Pérou">Pérou</span>
# <span class="light">(2)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTA4OC9kZWNlbm5pZS0xOTcwLw== item-content" title="Roumanie">Roumanie</span>
# <span class="light">(10)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTAzOS9kZWNlbm5pZS0xOTcwLw== item-content" title="Russie">Russie</span>
# <span class="light">(41)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTEzMy9kZWNlbm5pZS0xOTcwLw== item-content" title="République dominicaine">République dominicaine</span>
# <span class="light">(1)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTE2NS9kZWNlbm5pZS0xOTcwLw== item-content" title="République tchèque">République tchèque</span>
# <span class="light">(2)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTExMy9kZWNlbm5pZS0xOTcwLw== item-content" title="Singapour">Singapour</span>
# <span class="light">(1)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTEwMC9kZWNlbm5pZS0xOTcwLw== item-content" title="Slovaquie">Slovaquie</span>
# <span class="light">(8)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTA5OC9kZWNlbm5pZS0xOTcwLw== item-content" title="Sri Lanka">Sri Lanka</span>
# <span class="light">(3)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTAxMC9kZWNlbm5pZS0xOTcwLw== item-content" title="Suisse">Suisse</span>
# <span class="light">(73)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTA2Ny9kZWNlbm5pZS0xOTcwLw== item-content" title="Suède">Suède</span>
# <span class="light">(54)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTA5NS9kZWNlbm5pZS0xOTcwLw== item-content" title="Syrie">Syrie</span>
# <span class="light">(3)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTA4OS9kZWNlbm5pZS0xOTcwLw== item-content" title="Sénégal">Sénégal</span>
# <span class="light">(7)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTEwOS9kZWNlbm5pZS0xOTcwLw== item-content" title="Tadjikistan">Tadjikistan</span>
# <span class="light">(1)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTA0MC9kZWNlbm5pZS0xOTcwLw== item-content" title="Taïwan">Taïwan</span>
# <span class="light">(44)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTA0MS9kZWNlbm5pZS0xOTcwLw== item-content" title="Tchécoslovaquie">Tchécoslovaquie</span>
# <span class="light">(38)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTEyNy9kZWNlbm5pZS0xOTcwLw== item-content" title="Thaïlande">Thaïlande</span>
# <span class="light">(1)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTA1Mi9kZWNlbm5pZS0xOTcwLw== item-content" title="Tunisie">Tunisie</span>
# <span class="light">(9)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTAyNi9kZWNlbm5pZS0xOTcwLw== item-content" title="Turquie">Turquie</span>
# <span class="light">(79)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTEwNi9kZWNlbm5pZS0xOTcwLw== item-content" title="Ukraine">Ukraine</span>
# <span class="light">(2)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTE2MS9kZWNlbm5pZS0xOTcwLw== item-content" title="URSS">URSS</span>
# <span class="light">(75)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTA1NC9kZWNlbm5pZS0xOTcwLw== item-content" title="Vietnam">Vietnam</span>
# <span class="light">(3)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTA4Mi9kZWNlbm5pZS0xOTcwLw== item-content" title="Vénézuela">Vénézuela</span>
# <span class="light">(3)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTA2Ni9kZWNlbm5pZS0xOTcwLw== item-content" title="Yougoslavie">Yougoslavie</span>
# <span class="light">(47)</span> </li>
# <li class="filter-entity-item">
# <span class="ACrL2ZACrpbG1zL3BheXMtNTAzNi9kZWNlbm5pZS0xOTcwLw== item-content" title="Zimbabwé">Zimbabwé</span>
# <span class="light">(1)</span> </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="gd-col-middle">
# <div class="dropdown-custom-holder dropdown-custom-alter">
# <span class="what">Trier par</span>
# <div class="dropdown-custom js-dropdown">
# <span class="title">Popularité</span>
# <i class="btn"></i>
# <ul class="list">
# <li class="item">
# <span class="ACrL2ZACrpbG1zL2RlY2VubmllLTE5NzAv item-content">
# Popularité
# </span>
# </li>
# <li class="item">
# <span class="ACrL2ZACrpbG1zL25vdGVzL2RlY2VubmllLTE5NzAv item-content">
# Note spectateurs
# </span>
# </li>
# <li class="item">
# <span class="ACrL2ZACrpbG1zL3ByZXNzZS9kZWNlbm5pZS0xOTcwLw== item-content">
# Note presse
# </span>
# </li>
# <li class="item">
# <span class="ACrL2ZACrpbG1zL2FscGhhYmV0aXF1ZS9kZWNlbm5pZS0xOTcwLw== item-content">
# Ordre alphabétique
# </span>
# </li>
# </ul>
# </div>
# </div>
# <ul>
# <li class="mdl">
# <div class="card entity-card entity-card-list cf">
# <figure class="thumbnail">
# <span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT01MTc2Ny5odG1s thumbnail-container thumbnail-link" title="Un homme est mort">
# <img alt="Un homme est mort" class="thumbnail-img" height="420" src="https://fr.web.img6.acsta.net/c_310_420/medias/nmedia/18/73/04/48/19188221.jpg" width="310"/>
# </span>
# </figure>
# <div class="meta meta-affintiy-score">
# <h2 class="meta-title">
# <a class="meta-title-link" href="/film/fichefilm_gen_cfilm=51767.html">Un homme est mort</a>
# </h2>
# <div class="meta-body">
# <div class="meta-body-item meta-body-info">
# <span class="date">13 janvier 1973</span>
# <span class="spacer">|</span>
# 1h 44min
# <span class="spacer">|</span>
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDE4Lw== dark-grey-link">Policier</span>,
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDA4Lw== dark-grey-link">Drame</span>,
# <span class="ACrL2ZACrpbG1zL2dlbnJlLTEzMDIzLw== dark-grey-link">Thriller</span>
# </div>
# <div class="meta-body-item meta-body-direction">
# <span class="light">De</span>
# <span class="ACrL3BACrlcnNvbm5lL2ZpY2hlcGVyc29ubmVfZ2VuX2NwZXJzb25uZT0yMzQ2Lmh0bWw= dark-grey-link">Jacques Deray</span>
# </div>
# <div class="meta-body-item meta-body-actor">
# <span class="light">Avec</span>
# <span class="ACrL3BACrlcnNvbm5lL2ZpY2hlcGVyc29ubmVfZ2VuX2NwZXJzb25uZT04OTE0Mi5odG1s dark-grey-link">Georgia Engel</span>,
# <span class="ACrL3BACrlcnNvbm5lL2ZpY2hlcGVyc29ubmVfZ2VuX2NwZXJzb25uZT02ODIuaHRtbA== dark-grey-link">Jean-Louis Trintignant</span>,
# <span class="ACrL3BACrlcnNvbm5lL2ZpY2hlcGVyc29ubmVfZ2VuX2NwZXJzb25uZT0yNjE3Lmh0bWw= dark-grey-link"> Ann-Margret</span>
# </div>
# </div>
# <div class="js-affinity-badge" data-entity-id="TW92aWU6NTE3Njc="></div>
# </div>
# <div class="rating-holder rating-holder-2">
# <div class="rating-item">
# <div class="rating-item-content">
# <span class="ACrL2ZACrpbG0vZmljaGVmaWxtLTUxNzY3L2NyaXRpcXVlcy9zcGVjdGF0ZXVycy8= rating-title"> Spectateurs </span>
# <div class="stareval stareval-small stareval-theme-default"><div class="rating-mdl n30 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note">2,8</span></div>
# </div>
# </div>
# <div class="rating-item">
# <div class="rating-item-content js-user-friends-rating" data-entity-id="TW92aWU6NTE3Njc=" data-size="small" data-title="Mes amis ">
# <a class="rating-title" href="#">Mes amis </a>
# <div class="stareval stareval-small stareval-theme-default"><div class="rating-mdl n00 stareval-stars"><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div><div class="star icon"></div></div><span class="stareval-note no-rating">--</span></div>
# </div>
# </div>
# </div>
# <div class="synopsis">
# <div class="content-txt">
# Pour rembourser ses dettes, Lucien Bellon accepte de tuer le milliardaire Victor Kovacs.
# </div>
# </div>
# <div class="buttons-holder">
# <span class="ACrL2ZACrpbG0vZmljaGVmaWxtX2dlbl9jZmlsbT01MTc2Ny5odG1s#ovw-products button button-sm button-default-full" data-ga='{"hitType":"event","eventCategory":"op-svod","eventLabel":"streaming_button","dimension82":"51767-un_homme_est_mort","dimension10":"movies_all"}' data-ga-trigger="clic" data-jan='{"eventAction":"both","eventName":"svod_generic_button","movie_entity":"51767|un_homme_est_mort","series_entity":"undefined","site_route":"movies_all"}'>
# <span class="txt">Streaming</span>
# </span>
# ...
#         var JadIds    = ["dfp-interstitial","dfp-headerlink","dfp-masthead","dfp-atf","dfp-atf","dfp-mtf","dfp-mtf","dfp-autopromo","dfp-autopromo","dfp-btf","dfp-btf","dfp-footer","dfp-pulse"];
#         var WadsKeywords = {"route":"movies_all","site":"allocine_fr","page":"movies","mode":"async"};
#     </script>
# <script type="text/javascript">(function (win) {
#     win.AC = win.AC || {};
#     AC.config = {"releaseWeekDay":"Wednesday","locale":"fr_FR","lang":"fr","brand":"allocine","siteKey":"fr","graphCountryName":"FRANCE","display_provider":"jad","asset_version":"8f1a5eb377bd382a0e6a1e3f546dabda2ade9759","env":"prod","assetsUrls":{"css":{"secondary":"https:\/\/assets.allocine.fr\/skin\/css\/allocine\/secondary-styles.min.409487fb.css","font":"https:\/\/assets.allocine.fr\/skin\/css\/allocine\/font.min.7c570837.css"},"images":{"logo":"https:\/\/assets.allocine.fr\/skin\/img\/logo-allocine.7e88ee87.svg","bronson":"https:\/\/assets.allocine.fr\/skin\/img\/userspace\/bronson.e492ec8e.gif","seriously":"https:\/\/assets.allocine.fr\/skin\/img\/seriously.ffccba64.gif","walle":"https:\/\/assets.allocine.fr\/skin\/img\/userspace\/walle.5d973cbb.png","notFound":"https:\/\/assets.allocine.fr\/skin\/img\/userspace\/not-found.dec1f46f.gif","ghostBuster":"https:\/\/assets.allocine.fr\/skin\/img\/userspace\/ghostbuster.7c731e13.png","etoile":"https:\/\/assets.allocine.fr\/skin\/img\/etoiles.766780d2.png","onboarding":"https:\/\/assets.allocine.fr\/skin\/img\/allocine\/onboarding.a32c4541.png","suggestions":"https:\/\/assets.allocine.fr\/skin\/img\/suggestions.0009180e.png","macaron":"https:\/\/assets.allocine.fr\/skin\/img\/macaron.363298ee.png","cineRelax":"https:\/\/assets.allocine.fr\/skin\/img\/logo-cine-relax.9ddea53f.svg"}},"webedia_websites":["allocine.fr","www.academiedugout.fr","www.canalblog.com","www.over-blog.com","www.confidentielles.com","www.750g.com","www.alibabuy.com","www.chartsinfrance.net","www.dailyconso.com","www.easyvols.fr","www.easyvoyage.com","www.exponaute.com","www.forumjv.com","fr.ign.com","jeu.info","www.jeuxvideo.com","www.lebonguide.com","www.lofficielmode.com","www.millenium.org","www.purebreak.com","www.purecine.com","www.purefamille.com","www.purfans.com","www.pureloisirs.com","www.ozap.com","www.purepeople.com","www.puresaveurs.com","www.shopoon.fr","www.puresweethome.com","www.puretrend.com","www.terrafemina.com","www.yasmina.com","www.atyabtabkha.3a2ilati.com","www.3a2ilati.com","www.mashaheeri.com","www.mazyun.com","www.beyazperde.com","www.filmstarts.de","www.moviepilot.de","www.gamestar.de","www.onlinewelten.com","de.ign.com","www.gamespilot.de","www.heimgourmet.com","www.easyvoyage.de","www.adorocinema.com","br.ign.com","www.purepeople.com.br","www.purebreak.com.br","www.pureviagem.com.br","www.tudogostoso.com.br","www.receitas-sem-fronteiras.com","www.easyvoyage.co.uk","www.dealchecker.co.uk","www.gourmandize.com","www.sensacine.com","www.3djuegos.com","es.ign.com","www.easyviajar.com","www.rebanando.com","www.easyviaggio.com","www.tribugolosa.com"],"hosts":{"assets":"https:\/\/assets.allocine.fr","secure":"https:\/\/secure.allocine.fr","secureApi":"https:\/\/api-secure.allocine.fr","validation":"https:\/\/secure.allocine.fr","sso":"https:\/\/sso.allocine.fr","graph":"https:\/\/graph.allocine.fr","hostname":"allocine.fr"},"jan_config":{"src":"https:\/\/cdn.lib.getjan.io\/library\/allocine.js"},"ads":{"displayProvider":"jad","prerollProvider":"jad","postrollProvider":null,"postrollTrailerProvider":"jad","postrollProxy":"\/\/videos.allocine.fr","atf":"atf","slideshow":"slideshow","slideshownativebanner":"slideshownativebanner","positions":"dfp-atf,dfp-mtf,dfp-btf,dfp-interstitial,dfp-masthead,dfp-footer,dfp-slideshow,dfp-slideshownativebanner,dfp-sticky-amp,,,dfp-inread,,,,dfp-headerlink,,dfp-autopromo,dfp-pulse,dfp-nativebanner,dfp-nativebanner-ope,dfp-nativerectangle,dfp-nativebutton,dfp-nativevod,dfp-nativebooking,","nativebooking":"nativebooking"},"secureApiPartnerKey":"000042532791","facebook":{"appId":"99197768694","version":"v3.2","permissions":"public_profile email user_friends"},"google":{"appId":"472230823030.apps.googleusercontent.com","apiKey":"pxKT_spGOdGnt7MVJXcTGCGr","permissions":"https:\/\/www.googleapis.com\/auth\/userinfo.email https:\/\/www.googleapis.com\/auth\/plus.login","tagManagerId":"GTM-PL6PBF","analyticsUACode":"UA-597605-13","analyticsPartners":[],"reCaptc ...
#     AC.routing = {"base_url":"","routes":{"rewind_conf_json":{"tokens":[["text","\/_\/rewind_config.b2f7334f9c70a68943dbf98385751b234458e036.json"]],"defaults":{"_controller":"AppBundle\\Rewind\\Controller\\RewindConfController::rewindAction","_format":"json","options":{"expose":true},"_cache_control":{"enabled":true,"ttl":3600},"_universe":"default"},"requirements":[],"hosttokens":[],"methods":[],"schemes":[]},"fos_js_routing_js":{"tokens":[["variable",".","js|json","_format",true],["text","\/js\/routing"]],"defaults":{"_controller":"fos_js_routing.controller::indexAction","_format":"js","_cache_control":{"enabled":true,"ttl":3600},"_universe":"default"},"requirements":{"_format":"js|json"},"hosttokens":[],"methods":["GET"],"schemes":[]},"allocine__moviepage":{"tokens":[["text",".html"],["variable","=","[1-9]\\d*","movie",true],["text","\/film\/fichefilm_gen_cfilm"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::indexAction","_api":[{"entity":"MOVIE","mainParam":"movie","description":"Homepage","params":{"movie":"MOVIE"}}],"_brand":"allocine","_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_showtimes":{"tokens":[["text","\/"],["variable","-","[1-9]\\d*","movie",true],["text","\/seance\/film"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::showtimesAction","_api":[{"entity":"MOVIE","mainParam":"movie","description":"Showtimes","params":{"movie":"MOVIE"}}],"_brand":"allocine","_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_showtimes_place":{"tokens":[["text","\/"],["variable","-","\\d+","localization",true],["text","\/pres-de"],["variable","-","[1-9]\\d*","movie",true],["text","\/seance\/film"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::showtimesPlaceAction","_brand":"allocine","_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"localization":"\\d+","movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_showtimes_my_theaters":{"tokens":[["text","\/favoris\/seances\/"],["variable","-","[1-9]\\d*","movie",true],["text","\/seance\/film"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::showtimesMyTheatersAction","_brand":"allocine","_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_showtimes_lookup":{"tokens":[["text","\/recherche\/"],["variable","-","[1-9]\\d*","movie",true],["text","\/seance\/film"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::showtimesLookupAction","_brand":"allocine","_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_videos_trailer":{"tokens":[["text",".html"],["variable","=","[1-9]\\d*","movie",true],["text","&cfilm"],["variable","=","[1-9]\\d*","idMedia",true],["text","\/video\/player_gen_cmedia"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::videosTrailerAction","_brand":"allocine","_cache_control":{"enabled":true,"ttl":3600},"_universe":"moviepage"},"requirements":{"idMedia":"[1-9]\\d*","movie":"[1-9]\\d*"},"hosttokens":[["text","www.allocine.fr"]],"methods":["GET"],"schemes":[]},"allocine__moviepage_all_videos_trailer":{"tokens":[["text","\/toutes\/"],["variable","-","[1-9]\\d*","movie",true],["text","\/videos\/fichefilm"]],"defaults":{"_controller":"AppBundle\\Controller\\MoviePageController::allVideosTrailerAction","_brand":"allocine","_cache_control":{"enable ...
#     AC.route = 'movies_all';
# }(window));
# </script>
# <script src="https://assets.allocine.fr/js/website/translations-4e5c0e6c9dff92c49fa471319fec49c4.fr_FR.js"></script>
# <script src="https://assets.allocine.fr/js/website/website-common.e0dd554d7d10ff11a60d.js" type="text/javascript"></script>
# <script defer="" src="https://assets.allocine.fr/js/website/movies.c0944689a2b67f17bb03.js" type="text/javascript"></script>
# <script type="text/javascript">
#     var dataLayer = dataLayer || [{"site_route":"movies_all","site_section":"movies"}];
# </script>
# <noscript>
# <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-PL6PBF" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <script type="text/javascript">
#             var asyncDataLayers = [];
#             var jsEntities = {"TW92aWU6NTE3Njc=":{"id":"TW92aWU6NTE3Njc=","title":"Un homme est mort","social":{"user_note_i_want_to_see_count":38},"flags":{"isComingSoon":false},"releaseDate":"1973-01-13T00:00:00+01:00","poster":{"__typename":"InternalImage","id":"SW1hZ2U6OTAwMTQ3MzUzOA==","internalId":9001473538,"url":"https:\/\/fr.web.img3.acsta.net\/medias\/nmedia\/18\/73\/04\/48\/19188221.jpg","path":"\/medias\/nmedia\/18\/73\/04\/48\/19188221.jpg"},"nationality":[{"id":5001,"name":"France","localizedName":"France"},{"id":5020,"name":"Italy","localizedName":"Italie"},{"id":5002,"name":"USA","localizedName":"U.S.A."}],"productionYear":1972},"TW92aWU6Mzgz":{"id":"TW92aWU6Mzgz","title":"Josey Wales hors la loi","social":{"user_note_i_want_to_see_count":738},"flags":{"isComingSoon":false},"releaseDate":"1976-10-01T00:00:00+01:00","poster":{"__typename":"InternalImage","id":"SW1hZ2U6OTAwMTY1OTkxNw==","internalId":9001659917,"url":"https:\/\/fr.web.img6.acsta.net\/medias\/nmedia\/18\/65\/46\/98\/18864536.jpg","path":"\/medias\/nmedia\/18\/65\/46\/98\/18864536.jpg"},"nationality":[{"id":5002,"name":"USA","localizedName":"U.S.A."}],"productionYear":1976},"TW92aWU6NjY2":{"id":"TW92aWU6NjY2","title":"Emmanuelle","social":{"user_note_i_want_to_see_count":223},"flags":{"isComingSoon":false},"releaseDate":"1974-06-26T00:00:00+01:00","poster":null,"nationality":[{"id":5001,"name":"France","localizedName":"France"}],"productionYear":1974},"TW92aWU6MjIw":{"id":"TW92aWU6MjIw","title":"Johnny got his Gun","social":{"user_note_i_want_to_see_count":969},"flags":{"isComingSoon":false},"releaseDate":"1972-03-01T00:00:00+01:00","poster":{"__typename":"InternalImage","id":"SW1hZ2U6MTAwMDM1Njk4NA==","internalId":1000356984,"url":"https:\/\/fr.web.img2.acsta.net\/img\/64\/5f\/645f00a10ca75e74e6a521e9386bf54e.jpg","path":"\/img\/64\/5f\/645f00a10ca75e74e6a521e9386bf54e.jpg"},"nationality":[{"id":5002,"name":"USA","localizedName":"U.S.A."}],"productionYear":1971},"TW92aWU6MTAwNTE=":{"id":"TW92aWU6MTAwNTE=","title":"Les Naufrag\u00e9s de l'ile de la Tortue","social":{"user_note_i_want_to_see_count":118},"flags":{"isComingSoon":false},"releaseDate":"1976-10-06T00:00:00+01:00","poster":{"__typename":"InternalImage","id":"SW1hZ2U6MTAwMDMzODc5OQ==","internalId":1000338799,"url":"https:\/\/fr.web.img3.acsta.net\/img\/aa\/da\/aada5e33c31ec8a062b8b1b6445f89eb.jpg","path":"\/img\/aa\/da\/aada5e33c31ec8a062b8b1b6445f89eb.jpg"},"nationality":[{"id":5001,"name":"France","localizedName":"France"}],"productionYear":1974},"TW92aWU6NDQxOQ==":{"id":"TW92aWU6NDQxOQ==","title":"Diabolo Menthe","social":{"user_note_i_want_to_see_count":207},"flags":{"isComingSoon":false},"releaseDate":"2016-02-01T00:00:00+01:00","poster":{"__typename":"InternalImage","id":"SW1hZ2U6MjE0MjI2OTg=","internalId":21422698,"url":"https:\/\/fr.web.img6.acsta.net\/pictures\/17\/07\/13\/14\/37\/210923.jpg","path":"\/pictures\/17\/07\/13\/14\/37\/210923.jpg"},"nationality":[{"id":5001,"name":"France","localizedName":"France"}],"productionYear":1977},"TW92aWU6MTYyOA==":{"id":"TW92aWU6MTYyOA==","title":"Le Parrain","social":{"user_note_i_want_to_see_count":7915},"flags":{"isComingSoon":false},"releaseDate":"1972-10-18T00:00:00+01:00","poster":{"__typename":"InternalImage","id":"SW1hZ2U6MjE4ODU5MjA=","internalId":21885920,"url":"https:\/\/fr.web.img2.acsta.net\/pictures\/22\/01\/14\/08\/39\/1848157.jpg","path":"\/pictures\/22\/01\/14\/08\/39\/1848157.jpg"},"nationality":[{"id":5002,"name":"USA","localizedName":"U.S.A."}],"productionYear":1972},"TW92aWU6NjI=":{"id":"TW92aWU6NjI=","title":"Alien, le huiti\u00e8me passager","social":{"user_note_i_want_to_see_count":2412},"flags":{"isComingSoon":false},"releaseDate":"1979-09-12T00:00:00+02:00","poster":{"__typename":"InternalImage","id":"SW1hZ2U6OTAwMTY1NzUwMg==","internalId":9001657502,"url":"https:\/\/fr.web.img3.acsta.net\/medias\/nmedia\/18\/35\/14\/60\/18363837.jpg","path":"\/medias\/nmedia\/18\/35\/14\/60\/18363837.jpg"},"nationality":[{"id":5004, ...
#         </script>
# <script>
#     (function(win, undefined) {
#         var tests = [];
#
#         // add tests here
#         tests.push(function() {
#             return 'CSS' in win && CSS.supports('display', 'grid');
#         });
#
#         // run all tests
#         var length = tests.length;
#         var idx = 0;
#         var supported = true;
#
#         for (idx = 0; supported && idx < length; idx += 1) {
#             supported = tests[idx]();
#         }
#
#         // display banner
#         if (!supported) {
#             var doc = win.document;
#             var alertBanner = doc.createElement('div');
#             var alertContent = alertBanner.cloneNode('div'); // performence best pratice
#             var bannerText = doc.createTextNode("La version de votre navigateur n'est plus supportée, l'expérience sur le site sera dégradée. Si vous ne pouvez ni mettre à jour votre navigateur, ni en changer, sachez que le site est consultable sur mobile à la même adresse.");
#
#             alertBanner.className = "alert-deprecated-banner alert-info";
#             alertContent.className = "alert-content";
#
#             var body = doc.body;
#             var head = doc.getElementsByTagName('head')[0];
#
#             var header = doc.getElementById('main-header');
#             var link = doc.createElement('link');
#
#             alertContent.appendChild(bannerText);
#             alertBanner.appendChild(alertContent);
#
#             body.insertBefore(alertBanner, header || body.firstChild);
#             body.className += ' deprecated';
#
#             // @todo css deprecated
#             link.setAttribute('href', 'https\u003A\/\/assets.allocine.fr\/skin\/css\/allocine\/deprecated.min.ae3fd993.css');
#             link.setAttribute('rel', 'stylesheet');
#             link.setAttribute('type', 'text/css');
#             head.appendChild(link);
#         }
#     })(window);
# </script>
# </div>
# </body>
# </html>

# %%
# Fonction pour scraper une seule page
def scrape_page(page):
    response = requests.get(url + str(page))
    response.raise_for_status()
    
    soup = BeautifulSoup(response.text, 'lxml')
    page_movies = []

    for movie in soup.select('li.mdl'):
        title = movie.select_one('h2.meta-title').text.strip() if movie.select_one('h2.meta-title') else ''
        # On récupère l'url de l'affiche du film qui peut être soit en 'src' soit en 'data-src'
        img_tag = movie.select_one('img.thumbnail-img')
        if img_tag:
            poster = img_tag.get('data-src', img_tag.get('src', ''))
            if poster.startswith('data:image'):
                # Enregistrer l'image encodée en base64
                filename = f"poster_{title.replace(' ', '_')}.jpg"
                save_base64_image(poster, filename)
                poster = filename
        else:
            poster = ''
        rating = movie.select_one('span.stareval-note').text.strip() if movie.select_one('span.stareval-note') else ''
        author = movie.select_one('div.meta-body-item.meta-body-direction').text.strip().replace('\n', ' ').replace('|', ' ').replace('  ', ' ').replace('De', '') if movie.select_one('div.meta-body-item.meta-body-direction') else ''
        infos = movie.select_one('div.meta-body-item.meta-body-info').text.strip().split('\n|\n') if movie.select_one('div.meta-body-item.meta-body-info') else []
        date = infos[0] if len(infos) > 0 else ''
        duration = infos[1] if len(infos) > 1 else ''
        genre = infos[2].replace('\n', '') if len(infos) > 2 else ''
        actors = movie.select_one('div.meta-body-item.meta-body-actor').text.strip().replace('\n', ' ').replace('|', ' ').replace('  ', ' ').replace('Avec', '').replace(', ', ',') if movie.select_one('div.meta-body-item.meta-body-actor') else ''
        synopsis = movie.select_one('div.synopsis').text.strip() if movie.select_one('div.synopsis') else ''

        page_movies.append({
            'title': title,
            'poster': poster,
            'author': author,
            'date': date,
            'rating': rating,
            'genre': genre,
            'actors': actors,
            'duration': duration,
            'synopsis': synopsis
        })
    
    return page_movies

# %%
# Scraper plusieurs pages en parallèle
def scrape_all_pages(start_page, end_page):
    movies = []
    with ThreadPoolExecutor(max_workers=10) as executor:
        futures = [executor.submit(scrape_page, page) for page in range(start_page, end_page + 1)]
        for future in as_completed(futures):
            movies.extend(future.result())
    return movies

# %%
# On boucle sur le scraping de toutes les pages
url = "https://www.allocine.fr/films/decennie-2000/?page="
start = 0
end = 1531
for i in range(start, end, 100):
    print(f'Scraping des pages {i} à {i + 99}...')
    movies = scrape_all_pages(i, i + 99)
    print(f'Scraping pages Réussie !')
    # On écrit les données dans un fichier CSV
    with open('movies.csv', 'a', newline='') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=movies[0].keys())
        if i == start:
            writer.writeheader()
        writer.writerows(movies)
# Out:
# Scraping des pages 0 à 99...
# Scraping pages Réussie !
# Scraping des pages 100 à 199...
# Scraping pages Réussie !
# Scraping des pages 200 à 299...
# Scraping pages Réussie !
# Scraping des pages 300 à 399...
# Scraping pages Réussie !
# Scraping des pages 400 à 499...
# Scraping pages Réussie !
# Scraping des pages 500 à 599...
# Scraping pages Réussie !
# Scraping des pages 600 à 699...
# Scraping pages Réussie !
# Scraping des pages 700 à 799...
# Scraping pages Réussie !
# Scraping des pages 800 à 899...
# Scraping pages Réussie !
# Scraping des pages 900 à 999...
# Scraping pages Réussie !
# Scraping des pages 1000 à 1099...
# Scraping pages Réussie !
# Scraping des pages 1100 à 1199...
# Scraping pages Réussie !
# Scraping des pages 1200 à 1299...
# Scraping pages Réussie !
# Scraping des pages 1300 à 1399...
# Scraping pages Réussie !
# Scraping des pages 1400 à 1499...
# Scraping pages Réussie !
# Scraping des pages 1500 à 1599...
# Scraping pages Réussie !

# %%
# On boucle sur le scraping de toutes les pages 2010
url = "https://www.allocine.fr/films/decennie-2010/?page="
start = 0
end = 1768
for i in range(start, end, 100):
    print(f'Scraping des pages {i} à {i + 99}...')
    movies = scrape_all_pages(i, i + 99)
    print(f'Scraping pages Réussie !')
    # On écrit les données dans un fichier CSV
    with open('movies.csv', 'a', newline='') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=movies[0].keys())
        if i == start:
            writer.writeheader()
        writer.writerows(movies)
# Out:
# Scraping des pages 0 à 99...
# Scraping pages Réussie !
# Scraping des pages 100 à 199...
# Scraping pages Réussie !
# Scraping des pages 200 à 299...
# Scraping pages Réussie !
# Scraping des pages 300 à 399...
# Scraping pages Réussie !
# Scraping des pages 400 à 499...
# Scraping pages Réussie !
# Scraping des pages 500 à 599...
# Scraping pages Réussie !
# Scraping des pages 600 à 699...
# Scraping pages Réussie !
# Scraping des pages 700 à 799...
# Scraping pages Réussie !
# Scraping des pages 800 à 899...
# Scraping pages Réussie !
# Scraping des pages 900 à 999...
# Scraping pages Réussie !
# Scraping des pages 1000 à 1099...
# Scraping pages Réussie !
# Scraping des pages 1100 à 1199...
# Scraping pages Réussie !
# Scraping des pages 1200 à 1299...
# Scraping pages Réussie !
# Scraping des pages 1300 à 1399...
# Scraping pages Réussie !
# Scraping des pages 1400 à 1499...
# Scraping pages Réussie !
# Scraping des pages 1500 à 1599...
# Scraping pages Réussie !
# Scraping des pages 1600 à 1699...
# Scraping pages Réussie !
# Scraping des pages 1700 à 1799...
# Scraping pages Réussie !

# %%
# On boucle sur le scraping de toutes les pages 2020
url = "https://www.allocine.fr/films/decennie-2020/?page="
start = 0
end = 1116
for i in range(start, end, 100):
    print(f'Scraping des pages {i} à {i + 99}...')
    movies = scrape_all_pages(i, i + 99)
    print(f'Scraping pages Réussie !')
    # On écrit les données dans un fichier CSV
    with open('movies.csv', 'a', newline='') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=movies[0].keys())
        if i == start:
            writer.writeheader()
        writer.writerows(movies)
# Out:
# Scraping des pages 0 à 99...
# Scraping pages Réussie !
# Scraping des pages 100 à 199...
# Scraping pages Réussie !
# Scraping des pages 200 à 299...
# Scraping pages Réussie !
# Scraping des pages 300 à 399...
# Scraping pages Réussie !
# Scraping des pages 400 à 499...
# Scraping pages Réussie !
# Scraping des pages 500 à 599...
# Scraping pages Réussie !
# Scraping des pages 600 à 699...
# Scraping pages Réussie !
# Scraping des pages 700 à 799...
# Scraping pages Réussie !
# Scraping des pages 800 à 899...
# Scraping pages Réussie !
# Scraping des pages 900 à 999...
# Scraping pages Réussie !
# Scraping des pages 1000 à 1099...
# Scraping pages Réussie !
# Scraping des pages 1100 à 1199...
# Scraping pages Réussie !

# %%
# On test si les informations sont correctes en affichant les 5 premiers films
for movie in movies[:5]:
    print(movie)
# Out:
# {'title': 'Almost Had You', 'poster': 'https://fr.web.img4.acsta.net/c_310_420/pictures/22/06/10/17/51/0792577.jpg', 'author': ' Richard Omos-Iboyi', 'date': 'Date de sortie inconnue', 'rating': '', 'genre': '', 'actors': '', 'duration': 'Drame,\nRomance', 'synopsis': ''}
# {'title': 'A Far Shore', 'poster': 'https://fr.web.img6.acsta.net/c_310_420/commons/v9/common/empty/empty_portrait.png', 'author': ' Masaaki Kudô', 'date': 'Prochainement', 'rating': '', 'genre': 'Drame', 'actors': ' Kotone Hanase,Yumemi Ishida,Yoshiro Sakuma', 'duration': '2h 08min', 'synopsis': 'Aoi, 17 ans, travaille comme hôtesse dans une boîte de nuit afin de subvenir aux besoins de son petit garçon mais aussi de Masaya, son mari paresseux et violent. La jeune femme n’a guère d’horizon, perdue à Okinawa. Quelle chance Aoi a-t-elle de se sortir de ce marasme social ?'}
# {'title': 'La Balada del fénix', 'poster': 'https://fr.web.img6.acsta.net/c_310_420/commons/v9/common/empty/empty_portrait.png', 'author': ' Arturo Ambriz, Rodolfo Ambriz', 'date': 'Prochainement', 'rating': '', 'genre': 'Aventure,Animation,Fantastique', 'actors': ' Gael García Bernal', 'duration': '1h 40min', 'synopsis': 'Comprenant que son père mourant est un tyran, une princesse gobeline dotée de pouvoirs de feu magiques doit choisir entre sauver la vie du roi ou le royaume de sa soumission, sur les conseils du pire ennemi de son père, un sage phénix alchimiste.'}
# {'title': 'El último hereje', 'poster': 'https://fr.web.img6.acsta.net/c_310_420/commons/v9/common/empty/empty_portrait.png', 'author': ' Daniel de la Vega', 'date': 'Prochainement', 'rating': '', 'genre': '', 'actors': ' Victoria Almeida,Gloria Carrá,Germán Palacios', 'duration': 'Epouvante-horreur', 'synopsis': "Les convictions d'un porte-parole d'un nouvel athéisme sont mises à rude épreuve."}
# {'title': 'Paulo Freire: The Story of Revolution', 'poster': 'https://fr.web.img6.acsta.net/c_310_420/commons/v9/common/empty/empty_portrait.png', 'author': ' Cao Hamburger', 'date': 'Prochainement', 'rating': '', 'genre': '', 'actors': '', 'duration': 'Biopic', 'synopsis': "Le pédagogue Paulo Freire lance une initiative d'alphabétisation des adultes couronnée de succès dans l'humble ville d'Anglicos (Brésil) en 1964. Mais un coup d'État militaire soutenu par le gouvernement américain met fin au programme de Freire et le contraint à l'exil."}

# %%
# On importe numpy et pandas pour afficher les informations du fichier CSV
import numpy as np
import pandas as pd

# On lit le fichier CSV
df = pd.read_csv('movies.csv', delimiter=',')
df
# Out:
#                          title  \
# 0                 Viêt and Nam
# 1      Moi, Moche et Méchant 4
# 2              The Deliverance
# 3                 Bullet Train
# 4            Pauvres Créatures
# ...                        ...
# 17991               Emmanuelle
# 17992             Les Barbares
# 17993                   Tatami
# 17994            Speak No Evil
# 17995             À l’ancienne
#
#                                                   poster  \
# 0      https://fr.web.img2.acsta.net/c_310_420/img/e1...
# 1      https://fr.web.img5.acsta.net/c_310_420/img/cb...
# 2      https://fr.web.img6.acsta.net/c_310_420/img/ee...
# 3      https://fr.web.img6.acsta.net/c_310_420/pictur...
# 4      https://fr.web.img5.acsta.net/c_310_420/pictur...
# ...                                                  ...
# 17991  https://fr.web.img2.acsta.net/c_310_420/img/b6...
# 17992  https://fr.web.img4.acsta.net/c_310_420/img/08...
# 17993  https://fr.web.img6.acsta.net/c_310_420/img/46...
# 17994  https://fr.web.img5.acsta.net/c_310_420/img/3b...
# 17995  https://fr.web.img5.acsta.net/c_310_420/img/91...
#
#                                author               date rating  \
# 0                     Minh Quý Trương  25 septembre 2024    3,4
# 1          Patrick lage, Chris Renaud    10 juillet 2024    2,7
# 2                         Lee Daniels       30 août 2024    2,3
# 3                        David Leitch        3 août 2022    3,2
# 4                    Yorgos Lanthimos    17 janvier 2024    3,7
# ...                               ...                ...    ...
# 17991                    Audrey Diwan  25 septembre 2024    3,0
# 17992                       Julie lpy  18 septembre 2024    3,3
# 17993   Zar Amir Ebrahimi, Guy Nattiv   4 septembre 2024    3,8
# 17994                   James Watkins  18 septembre 2024    3,5
# 17995                    Hervé Mimran   4 septembre 2024    2,1
#
#                             genre  \
# 0                           Drame
# 1      Aventure,Animation,Comédie
# 2      Epouvante-horreur,Thriller
# 3                 Action,Thriller
# 4       Comédie,Drame,Fantastique
# ...                           ...
# 17991              Drame,Erotique
# 17992                     Comédie
# 17993                       Drame
# 17994           Epouvante-horreur
# 17995                     Comédie
#
#                                                 actors  duration  \
# 0         Thanh Hai Pham,Duy Bao Dinh Dao,Viet Tung Le  2h 09min
# 1                 Gad Elmaleh,Steve Carell,Audrey Lamy  1h 34min
# 2             Andra Day,Glenn Close,Anthony B. Jenkins  1h 51min
# 3             Brad Pitt,Joey King,Aaron Taylor-Johnson  2h 07min
# 4                 Emma Stone,Mark Ruffalo,Willem Dafoe  2h 21min
# ...                                                ...       ...
# 17991           Noémie Merlant,Will Sharpe,Naomi Watts  1h 47min
# 17992   Julie Delpy,Sandrine Kiberlain,Laurent Lafitte  1h 41min
# 17993       Arienne Mandi,Zar Amir Ebrahimi,Ash Goldeh  1h 43min
# 17994   James McAvoy,Mackenzie Davis,Aisling Franciosi  1h 50min
# 17995       Didier Bourdon,Gérard Darmon,Chantal Lauby  1h 30min
#
#                                                 synopsis
# 0      Nam et Viêt s’aiment. Tous les deux travaillen...
# 1      Gru, Lucy et les filles, Margo, Edith et Agnès...
# 2      Ebony et ses trois enfants rencontrent des inc...
# 3      Coccinelle est un assassin malchanceux et part...
# 4      Bella est une jeune femme ramenée à la vie par...
# ...                                                  ...
# 17991  Emmanuelle est en quête d’un plaisir perdu. El...
# 17992  A Paimpont, l’harmonie règne : parmi les habit...
# 17993  La judokate iranienne Leila et son entraîneuse...
# 17994  Une famille américaine passe le week-end dans ...
# 17995  Deux amis de toujours vivent sur une petite il...
#
# [17996 rows x 9 columns]

# %%
# On supprimme les films qui n'ont pas de genre ou de realisateur
df = df.dropna(subset=['genre', 'author'])
# On supprimme les doublons
df = df.drop_duplicates(subset=['title'])

# %%
# On supprime les films avec date : date de sortie inconnue
df = df[df['date'] != 'Date de sortie inconnue']
df = df[df['date'] != 'date']
df = df[df['date'] != 'Prochainement']
df
# Out:
#                                title  \
# 0                       Viêt and Nam
# 1            Moi, Moche et Méchant 4
# 2                    The Deliverance
# 3                       Bullet Train
# 4                  Pauvres Créatures
# ...                              ...
# 14749  Les biscuits magiques de Noël
# 15133                      Kala azar
# 15764            Où est passé Noël ?
# 16464        Un Noël presque royal !
# 16465  Lettres magiques au Père Noël
#
#                                                   poster  \
# 0      https://fr.web.img2.acsta.net/c_310_420/img/e1...
# 1      https://fr.web.img5.acsta.net/c_310_420/img/cb...
# 2      https://fr.web.img6.acsta.net/c_310_420/img/ee...
# 3      https://fr.web.img6.acsta.net/c_310_420/pictur...
# 4      https://fr.web.img5.acsta.net/c_310_420/pictur...
# ...                                                  ...
# 14749  https://fr.web.img6.acsta.net/c_310_420/img/54...
# 15133  https://fr.web.img6.acsta.net/c_310_420/common...
# 15764  https://fr.web.img6.acsta.net/c_310_420/img/57...
# 16464  https://fr.web.img3.acsta.net/c_310_420/img/ac...
# 16465  https://fr.web.img6.acsta.net/c_310_420/img/09...
#
#                             author               date rating  \
# 0                  Minh Quý Trương  25 septembre 2024    3,4
# 1       Patrick lage, Chris Renaud    10 juillet 2024    2,7
# 2                      Lee Daniels       30 août 2024    2,3
# 3                     David Leitch        3 août 2022    3,2
# 4                 Yorgos Lanthimos    17 janvier 2024    3,7
# ...                            ...                ...    ...
# 14749             Michael M. Scott    23 octobre 2024    NaN
# 15133             Janis Rafailidou        2 juin 2021    2,5
# 15764            Emily Moss Wilson    21 octobre 2024    NaN
# 16464              Jonathan Wright    22 octobre 2024    NaN
# 16465                John Stimpson    25 octobre 2024    NaN
#
#                             genre  \
# 0                           Drame
# 1      Aventure,Animation,Comédie
# 2      Epouvante-horreur,Thriller
# 3                 Action,Thriller
# 4       Comédie,Drame,Fantastique
# ...                           ...
# 14749                     Romance
# 15133                       Drame
# 15764                     Romance
# 16464                     Romance
# 16465                     Romance
#
#                                                   actors  duration  \
# 0           Thanh Hai Pham,Duy Bao Dinh Dao,Viet Tung Le  2h 09min
# 1                   Gad Elmaleh,Steve Carell,Audrey Lamy  1h 34min
# 2               Andra Day,Glenn Close,Anthony B. Jenkins  1h 51min
# 3               Brad Pitt,Joey King,Aaron Taylor-Johnson  2h 07min
# 4                   Emma Stone,Mark Ruffalo,Willem Dafoe  2h 21min
# ...                                                  ...       ...
# 14749   Merritt Patterson,Jon-Michael Ecker,Jorge Mon...  1h 23min
# 15133     Penelope Tsilika,Dimitris Lalos,Michele Valley  1h 32min
# 15764         Rachael Leigh Cook,Sam Page,Bailey Stender  1h 24min
# 16464               Brooke d'Orsay,Will Kemp,Taylor Love  1h 24min
# 16465      Katie Leclerc,Rafael de la Fuente,Laura Ceron  1h 24min
#
#                                                 synopsis
# 0      Nam et Viêt s’aiment. Tous les deux travaillen...
# 1      Gru, Lucy et les filles, Margo, Edith et Agnès...
# 2      Ebony et ses trois enfants rencontrent des inc...
# 3      Coccinelle est un assassin malchanceux et part...
# 4      Bella est une jeune femme ramenée à la vie par...
# ...                                                  ...
# 14749                                                NaN
# 15133  Penelope et Dimitris sont un couple de crémate...
# 15764                                                NaN
# 16464                                                NaN
# 16465                                                NaN
#
# [6360 rows x 9 columns]

# %%
# On efface les films dont les 2 derniers chiffres de la date de sortie ne se situent pas entre 70 et 79
df = df[df['date'].str[-2:].astype(int).between(20, 24)]
df
# Out:
#                                title  \
# 0                       Viêt and Nam
# 1            Moi, Moche et Méchant 4
# 2                    The Deliverance
# 3                       Bullet Train
# 4                  Pauvres Créatures
# ...                              ...
# 14749  Les biscuits magiques de Noël
# 15133                      Kala azar
# 15764            Où est passé Noël ?
# 16464        Un Noël presque royal !
# 16465  Lettres magiques au Père Noël
#
#                                                   poster  \
# 0      https://fr.web.img2.acsta.net/c_310_420/img/e1...
# 1      https://fr.web.img5.acsta.net/c_310_420/img/cb...
# 2      https://fr.web.img6.acsta.net/c_310_420/img/ee...
# 3      https://fr.web.img6.acsta.net/c_310_420/pictur...
# 4      https://fr.web.img5.acsta.net/c_310_420/pictur...
# ...                                                  ...
# 14749  https://fr.web.img6.acsta.net/c_310_420/img/54...
# 15133  https://fr.web.img6.acsta.net/c_310_420/common...
# 15764  https://fr.web.img6.acsta.net/c_310_420/img/57...
# 16464  https://fr.web.img3.acsta.net/c_310_420/img/ac...
# 16465  https://fr.web.img6.acsta.net/c_310_420/img/09...
#
#                             author               date rating  \
# 0                  Minh Quý Trương  25 septembre 2024    3,4
# 1       Patrick lage, Chris Renaud    10 juillet 2024    2,7
# 2                      Lee Daniels       30 août 2024    2,3
# 3                     David Leitch        3 août 2022    3,2
# 4                 Yorgos Lanthimos    17 janvier 2024    3,7
# ...                            ...                ...    ...
# 14749             Michael M. Scott    23 octobre 2024    NaN
# 15133             Janis Rafailidou        2 juin 2021    2,5
# 15764            Emily Moss Wilson    21 octobre 2024    NaN
# 16464              Jonathan Wright    22 octobre 2024    NaN
# 16465                John Stimpson    25 octobre 2024    NaN
#
#                             genre  \
# 0                           Drame
# 1      Aventure,Animation,Comédie
# 2      Epouvante-horreur,Thriller
# 3                 Action,Thriller
# 4       Comédie,Drame,Fantastique
# ...                           ...
# 14749                     Romance
# 15133                       Drame
# 15764                     Romance
# 16464                     Romance
# 16465                     Romance
#
#                                                   actors  duration  \
# 0           Thanh Hai Pham,Duy Bao Dinh Dao,Viet Tung Le  2h 09min
# 1                   Gad Elmaleh,Steve Carell,Audrey Lamy  1h 34min
# 2               Andra Day,Glenn Close,Anthony B. Jenkins  1h 51min
# 3               Brad Pitt,Joey King,Aaron Taylor-Johnson  2h 07min
# 4                   Emma Stone,Mark Ruffalo,Willem Dafoe  2h 21min
# ...                                                  ...       ...
# 14749   Merritt Patterson,Jon-Michael Ecker,Jorge Mon...  1h 23min
# 15133     Penelope Tsilika,Dimitris Lalos,Michele Valley  1h 32min
# 15764         Rachael Leigh Cook,Sam Page,Bailey Stender  1h 24min
# 16464               Brooke d'Orsay,Will Kemp,Taylor Love  1h 24min
# 16465      Katie Leclerc,Rafael de la Fuente,Laura Ceron  1h 24min
#
#                                                 synopsis
# 0      Nam et Viêt s’aiment. Tous les deux travaillen...
# 1      Gru, Lucy et les filles, Margo, Edith et Agnès...
# 2      Ebony et ses trois enfants rencontrent des inc...
# 3      Coccinelle est un assassin malchanceux et part...
# 4      Bella est une jeune femme ramenée à la vie par...
# ...                                                  ...
# 14749                                                NaN
# 15133  Penelope et Dimitris sont un couple de crémate...
# 15764                                                NaN
# 16464                                                NaN
# 16465                                                NaN
#
# [6259 rows x 9 columns]

# %%
df.to_csv('movies2020.csv', index=False)

# %%
# On récupère tous les csv (70 80 90 2000 2010 2020) et on les fusionne
df70 = pd.read_csv('movies70.csv', delimiter=',')
df80 = pd.read_csv('movies80.csv', delimiter=',')
df90 = pd.read_csv('movies90.csv', delimiter=',')
df2000 = pd.read_csv('movies2000.csv', delimiter=',')
df2010 = pd.read_csv('movies2010.csv', delimiter=',')
df2020 = pd.read_csv('movies2020.csv', delimiter=',')
df_cleaned = pd.concat([df70, df80, df90, df2000, df2010, df2020])
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 24874 entries, 0 to 6258
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     24874 non-null  object
#  1   poster    24874 non-null  object
#  2   author    24874 non-null  object
#  3   date      24874 non-null  object
#  4   rating    23894 non-null  object
#  5   genre     24874 non-null  object
#  6   actors    24540 non-null  object
#  7   duration  24874 non-null  object
#  8   synopsis  23885 non-null  object
# dtypes: object(9)
# memory usage: 1.9+ MB

# %%
# on cope le fichier dataframe dans un fichier CSV
df_cleaned.to_csv('movies_cleaned.csv', index=False)
